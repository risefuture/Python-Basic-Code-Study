# %% [markdown]
# Jump to python
# ==

# %% [markdown]
# 자료형
#  : 프로그래밍을 할 때 쓰이는 숫자, 문자열 등 자료 형태로 사용하는 모든 것
#  --

# %% [markdown]
# 1. 숫자형 : 숫자 형태로 이루어진 자료형 (정수, 실수, 8진수, 16진수)

# %% [markdown]
# > * 정수형(Integer) : 정수를 뜻하는 자료형

# %%
a = 123
print(a)
# Out:
# 123

# %%
a = -178
print(a)
# Out:
# -178

# %%
a = 0
print(a)
